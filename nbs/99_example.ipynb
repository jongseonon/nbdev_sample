# %% [markdown]
# # example
#
# > example of using streamlit in a jupyter notebook
#
# [![Streamlit App](https://static.streamlit.io/badges/streamlit_badge_black_white.svg)](https://ddobrinskiy-jupyter.streamlit.app/)
#
#
# In this examle we use [nbdev](https://nbdev.fast.ai/) to export only the relevant cells of our notebook to `.py` file
#
# - start the cells you want exported with the `#|export` or `#|exporti` directive
#
# - run `nb_export` to convert the `.ipynb` to `.py`
#
# ```python
# from nbdev.export import nb_export
# nb_export('99_example.ipynb', lib_path='.', name='example')
# ```
#
# Alternatively you can use native `nbconvert` from bash, but nbdev is superior :)

# %%
#| hide
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| hide

from datetime import datetime

import streamlit as st

# from streamlit_jupyter import StreamlitPatcher, tqdm

# %%
#| hide

# sp = StreamlitPatcher()
# sp.jupyter()  # register patcher with streamlit

# %%
#| export
st.title("Example")
# Out:
# 2025-11-06 02:11:27.756 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:27.932
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/conda/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-06 02:11:27.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:27.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export
st.markdown(
    """

This is a test page demonstrating the use of `streamlit_jupyter`.

If you're seeing this in jupyter, then it's working!

"""
)
# Out:
# 2025-11-06 02:11:27.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:27.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:27.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| hide

# sp.registered_methods

# %%
#| export 

name = st.text_input("What's your name?", "John")
# Out:
# 2025-11-06 02:11:28.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.048 Session state does not function when running a script without `streamlit run`
# 2025-11-06 02:11:28.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

date = st.date_input("Choose a date", datetime.now().date())
# Out:
# 2025-11-06 02:11:28.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

st.markdown(f"## Hello {name}!\n## The date is {date.strftime('%Y-%m-%d')}")
# Out:
# 2025-11-06 02:11:28.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

import time

import pandas as pd

st.subheader("A cached dataframe")


@st.cache_data()
def get_data(date):
    for i in tqdm(range(10)):
        time.sleep(0.1)
    return pd.DataFrame(
        {"date": pd.date_range(date, periods=3), "c": [7, 8, 5], "d": [10, 11, 7]}
    ).set_index("date")


df = get_data(date)
st.write(df)
# Out:
# 2025-11-06 02:11:28.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.461 No runtime found, using MemoryCacheStorageManager
# 2025-11-06 02:11:28.462 No runtime found, using MemoryCacheStorageManager
# 2025-11-06 02:11:28.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 19
#      13         time.sleep(0.1)
#      14     return pd.DataFrame(
#      15         {"date": pd.date_range(date, periods=3), "c": [7, 8, 5], "d": [10, 11, 7]}
#      16     ).set_index("date")
# ---> 19 df = get_data(date)
#      20 st.write(df)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:228, in CachedFunc.__call__(self, *args, **kwargs)
#     225     else:
#     226         spinner_message = f"Running `{name}(...)`."
# --> 228 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:270, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     264 spinner_or_no_context = (
#     265     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     266     if spinner_message is not None and not is_nested_cache_function
#     267     else contextlib.nullcontext()
#     268 )
#     269 with spinner_or_no_context:
# --> 270     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:329, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     325 # We acquired the lock before any other thread. Compute the value!
#     326 with self._info.cached_message_replay_ctx.calling_cached_function(
#     327     self._info.func
#     328 ):
# --> 329     computed_value = self._info.func(*func_args, **func_kwargs)
#     331 # We've computed our value, and now we need to write it back to the cache
#     332 # along with any "replay messages" that were generated during value computation.
#     333 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[11], line 12, in get_data(date)
#      10 @st.cache_data()
#      11 def get_data(date):
# ---> 12     for i in tqdm(range(10)):
#      13         time.sleep(0.1)
#      14     return pd.DataFrame(
#      15         {"date": pd.date_range(date, periods=3), "c": [7, 8, 5], "d": [10, 11, 7]}
#      16     ).set_index("date")
#
# NameError: name 'tqdm' is not defined

# %%
#| export

st.subheader("Data Editor")
df = pd.DataFrame(
    [
        {
            "command": "st.selectbox",
            "rating": 4,
            "is_widget": True,
        },
        {
            "command": "st.balloons",
            "rating": 5,
            "is_widget": False,
        },
        {
            "command": "st.time_input",
            "rating": 3,
            "is_widget": True,
        },
    ]
)
edited_df = st.data_editor(df)

# %%
#| export


st.subheader("One more cache example")


@st.cache_resource(ttl=3600)
def get_resource():
    st.write("Getting resource...")
    for i in tqdm(range(5)):
        time.sleep(0.1)
    return {
        "foo": "bar",
        "baz": [1, 2, 3],
        "qux": {"a": 1, "b": 2, "c": 3},
    }


records = get_resource()
st.json(records)
# Out:
# 2025-11-06 02:11:28.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 19
#      11         time.sleep(0.1)
#      12     return {
#      13         "foo": "bar",
#      14         "baz": [1, 2, 3],
#      15         "qux": {"a": 1, "b": 2, "c": 3},
#      16     }
# ---> 19 records = get_resource()
#      20 st.json(records)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:228, in CachedFunc.__call__(self, *args, **kwargs)
#     225     else:
#     226         spinner_message = f"Running `{name}(...)`."
# --> 228 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:270, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     264 spinner_or_no_context = (
#     265     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     266     if spinner_message is not None and not is_nested_cache_function
#     267     else contextlib.nullcontext()
#     268 )
#     269 with spinner_or_no_context:
# --> 270     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/streamlit/runtime/caching/cache_utils.py:329, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     325 # We acquired the lock before any other thread. Compute the value!
#     326 with self._info.cached_message_replay_ctx.calling_cached_function(
#     327     self._info.func
#     328 ):
# --> 329     computed_value = self._info.func(*func_args, **func_kwargs)
#     331 # We've computed our value, and now we need to write it back to the cache
#     332 # along with any "replay messages" that were generated during value computation.
#     333 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[12], line 10, in get_resource()
#       7 @st.cache_resource(ttl=3600)
#       8 def get_resource():
#       9     st.write("Getting resource...")
# ---> 10     for i in tqdm(range(5)):
#      11         time.sleep(0.1)
#      12     return {
#      13         "foo": "bar",
#      14         "baz": [1, 2, 3],
#      15         "qux": {"a": 1, "b": 2, "c": 3},
#      16     }
#
# NameError: name 'tqdm' is not defined

# %%
#| export

st.subheader("Ploting")

import plotly.express as px

df_daily = df[["rating"]].mean(axis="columns").rename("daily_average")
fig = px.line(df_daily, title="Daily mean", width=600)
st.write(fig)
# Out:
# 2025-11-06 02:11:28.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       3 st.subheader("Ploting")
#       5 import plotly.express as px
# ----> 7 df_daily = df[["rating"]].mean(axis="columns").rename("daily_average")
#       8 fig = px.line(df_daily, title="Daily mean", width=600)
#       9 st.write(fig)
#
# NameError: name 'df' is not defined

# %%
#| export

st.metric("Speed", 300, 210, delta_color="normal", label_visibility="visible")
# Out:
# 2025-11-06 02:11:29.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

st.metric("Speed", 300, 210)
# Out:
# 2025-11-06 02:11:29.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

st.code("print(1+1)", language="python")
# Out:
# 2025-11-06 02:11:29.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

show_code = st.checkbox("Show code", value=True)
# Out:
# 2025-11-06 02:11:29.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

if show_code:
    st.code("[i**2 for i in range(100)]")
# Out:
# 2025-11-06 02:11:29.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

option = st.radio("Choose one option", options=["foo", "bar"], index=1)
# Out:
# 2025-11-06 02:11:29.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

option = st.selectbox("Selectbox: ", options=["Jane", "Bob", "Alice"], index=0)
# Out:
# 2025-11-06 02:11:29.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:29.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

options = st.multiselect("Multiselect: ", options=["python", "golang", "julia", "rust"])
# Out:
# 2025-11-06 02:11:30.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

options = st.multiselect(
    "Multiselect with defaults: ",
    options=["nbdev", "streamlit", "jupyter", "fastcore"],
    default=["jupyter", "streamlit"],
)
# Out:
# 2025-11-06 02:11:30.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export
st.subheader("st.text:")
st.text("This is a text")
st.text("This is \n multiline text")
st.code("This is multiline \n code", language=None)
# Out:
# 2025-11-06 02:11:30.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:30.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# from nbdev.export import nb_export

# nb_export("99_example.ipynb", lib_path="./", name="example")

# %%
# !nbdev_docs

# %%
# !streamlit run example.py

# %%
# !jupyter nbconvert --to html "99_example.ipynb"
