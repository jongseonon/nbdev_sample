# %% [markdown]
# # example
#
# > example of using streamlit in a jupyter notebook
#
# [![Streamlit App](https://static.streamlit.io/badges/streamlit_badge_black_white.svg)](https://ddobrinskiy-jupyter.streamlit.app/)
#
#
# In this examle we use [nbdev](https://nbdev.fast.ai/) to export only the relevant cells of our notebook to `.py` file
#
# - start the cells you want exported with the `#|export` or `#|exporti` directive
#
# - run `nb_export` to convert the `.ipynb` to `.py`
#
# ```python
# from nbdev.export import nb_export
# nb_export('99_example.ipynb', lib_path='.', name='example')
# ```
#
# Alternatively you can use native `nbconvert` from bash, but nbdev is superior :)

# %%
#| hide
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| hide

from datetime import datetime

import streamlit as st

from streamlit_jupyter import StreamlitPatcher, tqdm

# %%
#| hide

# sp = StreamlitPatcher()
# sp.jupyter()  # register patcher with streamlit

# %%
#| export
st.title("Example")
# Out:
# 2025-11-06 03:32:28.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:28.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:28.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export
st.markdown(
    """

This is a test page demonstrating the use of `streamlit_jupyter`.

If you're seeing this in jupyter, then it's working!

"""
)
# Out:
# 2025-11-06 03:32:30.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:30.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:30.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| hide

# sp.registered_methods

# %%
#| export 

name = st.text_input("What's your name?", "John")
# Out:
# 2025-11-06 03:32:32.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:32.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

date = st.date_input("Choose a date", datetime.now().date())
# Out:
# 2025-11-06 03:32:34.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:34.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:34.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:34.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:34.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:34.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

st.markdown(f"## Hello {name}!\n## The date is {date.strftime('%Y-%m-%d')}")
# Out:
# 2025-11-06 03:32:37.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:37.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:37.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

import time

import pandas as pd

st.subheader("A cached dataframe")


@st.cache_data()
def get_data(date):
    for i in tqdm(range(10)):
        time.sleep(0.1)
    return pd.DataFrame(
        {"date": pd.date_range(date, periods=3), "c": [7, 8, 5], "d": [10, 11, 7]}
    ).set_index("date")


df = get_data(date)
st.write(df)
# Out:
# 2025-11-06 03:32:38.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.990 No runtime found, using MemoryCacheStorageManager
# 2025-11-06 03:32:38.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:38.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-11-06 03:32:39.499 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:39.500 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:39.501 Thread 'Thread-7': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:40.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

st.subheader("Data Editor")
df = pd.DataFrame(
    [
        {
            "command": "st.selectbox",
            "rating": 4,
            "is_widget": True,
        },
        {
            "command": "st.balloons",
            "rating": 5,
            "is_widget": False,
        },
        {
            "command": "st.time_input",
            "rating": 3,
            "is_widget": True,
        },
    ]
)
edited_df = st.data_editor(df)
# Out:
# 2025-11-06 03:32:42.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:42.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export


st.subheader("One more cache example")


@st.cache_resource(ttl=3600)
def get_resource():
    st.write("Getting resource...")
    for i in tqdm(range(5)):
        time.sleep(0.1)
    return {
        "foo": "bar",
        "baz": [1, 2, 3],
        "qux": {"a": 1, "b": 2, "c": 3},
    }


records = get_resource()
st.json(records)
# Out:
# 2025-11-06 03:32:44.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-11-06 03:32:44.604 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.605 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.606 Thread 'Thread-9': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:44.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

st.subheader("Ploting")

import plotly.express as px

df_daily = df[["rating"]].mean(axis="columns").rename("daily_average")
fig = px.line(df_daily, title="Daily mean", width=600)
st.write(fig)
# Out:
# 2025-11-06 02:11:28.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 02:11:28.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       3 st.subheader("Ploting")
#       5 import plotly.express as px
# ----> 7 df_daily = df[["rating"]].mean(axis="columns").rename("daily_average")
#       8 fig = px.line(df_daily, title="Daily mean", width=600)
#       9 st.write(fig)
#
# NameError: name 'df' is not defined

# %%
#| export

st.metric("Speed", 300, 210, delta_color="normal", label_visibility="visible")
# Out:
# 2025-11-06 03:32:45.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:45.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:45.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

st.metric("Speed", 300, 210)
# Out:
# 2025-11-06 03:32:46.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:46.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:46.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

st.code("print(1+1)", language="python")
# Out:
# 2025-11-06 03:32:46.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:46.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:46.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#| export

show_code = st.checkbox("Show code", value=True)
# Out:
# 2025-11-06 03:32:47.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

if show_code:
    st.code("[i**2 for i in range(100)]")
# Out:
# 2025-11-06 03:32:47.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:47.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

option = st.radio("Choose one option", options=["foo", "bar"], index=1)
# Out:
# 2025-11-06 03:32:48.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

option = st.selectbox("Selectbox: ", options=["Jane", "Bob", "Alice"], index=0)
# Out:
# 2025-11-06 03:32:48.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

options = st.multiselect("Multiselect: ", options=["python", "golang", "julia", "rust"])
# Out:
# 2025-11-06 03:32:48.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export

options = st.multiselect(
    "Multiselect with defaults: ",
    options=["nbdev", "streamlit", "jupyter", "fastcore"],
    default=["jupyter", "streamlit"],
)
# Out:
# 2025-11-06 03:32:48.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#| export
st.subheader("st.text:")
st.text("This is a text")
st.text("This is \n multiline text")
st.code("This is multiline \n code", language=None)
# Out:
# 2025-11-06 03:32:48.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 03:32:48.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# from nbdev.export import nb_export

# nb_export("99_example.ipynb", lib_path="./", name="example")

# %%
# !nbdev_docs

# %%
# !streamlit run example.py

# %%
# !jupyter nbconvert --to html "99_example.ipynb"
